# %% [markdown]
# - train e val possono essere semanticamente molto vicini rispetto a test
# - Monte carlo dropout per capire gli intervalli di confidenza del nostro modello (https://arxiv.org/abs/1506.02142)
# - Usare una rete di segmentazione può aiutare
# - Non ci sono dati riguardo ai pazienti
# - guarda correlazione tra morfologia dei vasi segmentati e malattia
# - images from glaucoma patients tend to have fewer annotated pixels and lower illumination and color distortion scores. We suspect this is because most glaucoma patients are older and may have more opacity in their refractive media, causing insufficient illumination, which would then influence the annotation ratio
# - different types of amd
# - 4 stadi di diabetic retinopathy
# - lo split è stato fatto stratificato tra le classi, per mantenere la proporzione orginale delle classi dentro ciascun set
